# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.11.0+cu128
# True
# NVIDIA GeForce RTX 5060 Ti

# %%
import torch_geometric
print(torch_geometric.__version__)
# Out:
# 2.8.0.post1

# %%
import setproctitle

# %%
# !python AnyGraph\main.py \
    --load_model pretrain_link1 \
    --dataset_setting link1 \
    --epoch 0
# Out:
# 2026-07-28 16:32:25.715257: Start
# 2026-07-28 16:32:25.715257: Loading dataset amazon-book
# Dataset: amazon-book, User num: 52643, Item num: 91599, Node num: 144242, Edge num: 2380730
# 2026-07-28 16:32:28.525812: Loading dataset amazon_textfeat
# Dataset: amazon_textfeat, User num: 11000, Item num: 9332, Node num: 20332, Edge num: 120464
# 2026-07-28 16:32:29.529308: Loading dataset citation-2019
# Dataset: citation-2019, Node num: 765658, Edge num: 1917381
# 2026-07-28 16:32:45.527241: Loading dataset citation-classic
# Dataset: citation-classic, Node num: 1016241, Edge num: 5565798
# 2026-07-28 16:34:19.056536: Loading dataset citeseer
# Dataset: citeseer, Node num: 3327, Edge num: 9104
# 2026-07-28 16:34:20.180886: Loading dataset email-Enron
# Dataset: email-Enron, Node num: 36692, Edge num: 367662
# 2026-07-28 16:34:21.965671: Loading dataset p2p-Gnutella06
# Dataset: p2p-Gnutella06, Node num: 8717, Edge num: 31525
# 2026-07-28 16:34:22.171445: Loading dataset ppa
# ...

# %%
# !python AnyGraph\main.py \
    --load_model pretrain_link1 \
    --dataset_setting amazon-book \
    --epoch 0
# Out:
# 2026-07-28 16:47:36.338604: Start
# 2026-07-28 16:47:36.338604: Loading dataset amazon-book
# Dataset: amazon-book, User num: 52643, Item num: 91599, Node num: 144242, Edge num: 2380730
# 2026-07-28 16:47:38.287952: Load Data
# ['amazon-book']
# Test group 0 ['amazon-book']
# Total params: 16.87552
# Trainable params: 16.87552
# Non-trainable params: 0.0
# 2026-07-28 16:47:38.389569: Model Prepared
# 2026-07-28 16:47:59.008208: Model Loaded
# 2026-07-28 16:48:50.213977: Steps 0/205: recall = 14.13, ndcg = 16.66
# 2026-07-28 16:48:50.239401: Steps 1/205: recall = 16.71, ndcg = 18.44
# 2026-07-28 16:48:50.260325: Steps 2/205: recall = 11.69, ndcg = 12.71
# 2026-07-28 16:48:50.284184: Steps 3/205: recall = 11.44, ndcg = 10.86
# 2026-07-28 16:48:50.305929: Steps 4/205: recall = 13.02, ndcg = 12.47
# 2026-07-28 16:48:50.329905: Steps 5/205: recall = 8.71, ndcg = 7.24
# 2026-07-28 16:48:50.348041: Steps 6/205: recall = 9.66, ndcg = 7.98
# ...

# %%
# !python AnyGraph\node_classification\main.py --load_model pretrain_link2 --epoch 0 --dataset_setting node
# Out:
# 2026-07-28 17:13:04.210179: Start
# 2026-07-28 17:13:04.210179: Loading dataset arxiv
# Dataset: arxiv, Node num: 169383, Edge num: 1456326
# 2026-07-28 17:13:08.578322: Loading dataset cora
# Dataset: cora, Node num: 25191, Edge num: 121912
# 2026-07-28 17:13:08.969561: Loading dataset home
# Dataset: home, Node num: 9795, Edge num: 149463
# 2026-07-28 17:13:09.263424: Loading dataset pubmed
# Dataset: pubmed, Node num: 19720, Edge num: 124138
# 2026-07-28 17:13:09.562004: Loading dataset tech
# Dataset: tech, Node num: 47431, Edge num: 2162611
# 2026-07-28 17:13:12.395139: Load Data
# ['arxiv', 'cora', 'home', 'pubmed', 'tech']
# Test group 0 ['arxiv', 'cora', 'home', 'pubmed', 'tech']
# Total params: 16.87552
# Trainable params: 16.87552
# Non-trainable params: 0.0
# 2026-07-28 17:13:12.511636: Model Prepared
# 2026-07-28 17:13:20.380611: Model Loaded
# 2026-07-28 17:13:33.376463: Steps 0/190: hit = 162, tot = 256
# 2026-07-28 17:13:33.378465: Steps 1/190: hit = 330, tot = 512
# ...
