# %%
# !python OpenGraph\link_prediction\main.py --load pretrn_gen1 --epoch 0 --data_dir "C:\Mestrado\Graph_Pruning\OpenGraph\datasets"
# Out:
# 2026-09-02 16:31:31.681418: Start
# Dataset: ml1m, User num: 6040, Item num: 3706, Node num: 9746, Edge num: 720152
# Dataset: collab, Node num: 235868, Edge num: 1935264
# Dataset: gen1, User num: 32200, Item num: 18861, Node num: 51061, Edge num: 268007
# Dataset: ml10m, User num: 69878, Item num: 10677, Node num: 80555, Edge num: 7200040
# 2026-09-02 16:31:42.208459: Load Data
# Total params: 25.1904
# Trainable params: 25.1904
# Non-trainable params: 0.0
# 2026-09-02 16:31:42.323097: Model Prepared
# Loading model from: c:\Mestrado\Graph_Pruning\OpenGraph\Models\pretrn_gen1.mod
# Loading history from: c:\Mestrado\Graph_Pruning\OpenGraph\History\pretrn_gen1.his
# 2026-09-02 16:31:42.390946: Model Loaded
# 2026-09-02 16:31:42.684787: Steps 0/23: recall = 43.38, ndcg = 57.54
# 2026-09-02 16:31:42.721575: Steps 1/23: recall = 42.23, ndcg = 55.30
# 2026-09-02 16:31:42.760160: Steps 2/23: recall = 46.36, ndcg = 64.33
# ...

# %%
# !python OpenGraph\node_classification\main.py --load pretrn_gen1 --epoch 0 --tstdata cora  --data_dir "C:\Mestrado\Graph_Pruning\OpenGraph\datasets"
# Out:
# 2026-09-02 17:56:17.175023: Start
# Dataset: cora, Node num: 2715, Edge num: 11836
# 2026-09-02 17:56:17.601328: Load Data
# Total params: 25.1904
# Trainable params: 25.1904
# Non-trainable params: 0.0
# 2026-09-02 17:56:17.734646: Model Prepared
# Loading model from: c:\Mestrado\Graph_Pruning\OpenGraph\Models\pretrn_gen1.mod
# Loading history from: c:\Mestrado\Graph_Pruning\OpenGraph\History\pretrn_gen1.his
# 2026-09-02 17:56:17.811330: Model Loaded
# 2026-09-02 17:56:17.924024: Steps 0/3: hit = 211, tot = 256
# 2026-09-02 17:56:17.930737: Steps 1/3: hit = 397, tot = 512
# 2026-09-02 17:56:17.931740: Steps 2/3: hit = 585, tot = 768
# 2026-09-02 17:56:17.931740: Steps 3/3: hit = 757, tot = 1000
# 2026-09-02 17:56:17.952445: Epoch 0/0, cora Test: Acc = 0.7570, F1 = 0.7497
# 2026-09-02 17:56:18.118408: Steps 0/3: hit = 217, tot = 256
# 2026-09-02 17:56:18.119410: Steps 1/3: hit = 405, tot = 512
# 2026-09-02 17:56:18.120755: Steps 2/3: hit = 588, tot = 768
# ...
